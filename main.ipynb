# %%
from google.colab import drive

# %%
drive.mount('/content/drive/',force_remount=True)
# Out:
# Mounted at /content/drive/

# %%
# !ls
# Out:
# drive  sample_data

# %%
parent_folder="drive/Shareddrives/Image-Text-Retrieval/deepcca"

# %%
# !unzip "drive/Shareddrives/Image-Text-Retrieval/dataset.zip" -d "/content"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/dataset/5501.jpg
#   inflating: /content/dataset/5502.jpg
#   inflating: /content/dataset/5503.jpg
#   inflating: /content/dataset/5504.jpg
#   inflating: /content/dataset/5505.jpg
#   inflating: /content/dataset/5506.jpg
#   inflating: /content/dataset/5507.jpg
#   inflating: /content/dataset/5508.jpg
#   inflating: /content/dataset/5509.jpg
#   inflating: /content/dataset/551.jpg
#   inflating: /content/dataset/5510.jpg
#   inflating: /content/dataset/5511.jpg
#   inflating: /content/dataset/5512.jpg
#   inflating: /content/dataset/5513.jpg
#   inflating: /content/dataset/5514.jpg
#   inflating: /content/dataset/5515.jpg
#   inflating: /content/dataset/5516.jpg
#   inflating: /content/dataset/5517.jpg
#   inflating: /content/dataset/5518.jpg
#   inflating: /content/dataset/5519.jpg
#   inflating: /content/dataset/552.jpg
#   inflating: /content/dataset/5520.jpg
#   inflating: /content/dataset/5521.jpg
# ...

# %%
# !python3 drive/Shareddrives/Image-Text-Retrieval/deepcca_gpu/data/make_json.py
# Out:
# 12305

# %%
# !sh drive/Shareddrives/Image-Text-Retrieval/deepcca_gpu/my_code/datasets/data.sh
# Out:
# Preprocessing dataset
# start build vodabulary
# Total words: 1418
# Words in vocab: 812
# number of bad words: 606/1418 = 42.74%
# number of words in vocab: 812/1418 = 57.26%
# number of Null: 787/1418 = 55.50%
# Process metadata done!
# Total 9844 captions 9844 images 9844 identities in train
# Process metadata done!
# Total 1230 captions 1230 images 1230 identities in val
# Process metadata done!
# Total 1231 captions 1231 images 1231 identities in test
# Process decodedata done!
# Process decodedata done!
# Process decodedata done!
# =========== Arrange by id=============================
# Save dataset
# =========== Arrange by id=============================
# Save dataset
# =========== Arrange by id=============================
# Save dataset

# %%
# !python3 drive/Shareddrives/Image-Text-Retrieval/deepcca_gpu/my_code/scripts/trainer.py
# Out:
# drive/Shareddrives/Image-Text-Retrieval/deepcca_gpu/data/model_data/lr-0.0002-decay-0.9-batch-16/1.pth.tar
# 0
# True
# ...

# %%
drive.flush_and_unmount()

# %%
#@title
